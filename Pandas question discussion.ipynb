# %%
#wap to find the location of the house where the number of bathroom is min. 2
#wap to find the price of the house where the location is "Rajaji Nagar".
# wap to find the house where the number of bathroom is 0.
#wap to find the society where the price of the house is in between 500-100.
#wap to find the the house where number of balcony is max. 3
#wap to find the house in "Yemlur" with min size of the house is 3bhk.
#wap to find the house in 'Indira nagar' and try to find when you can move into 
# the house.


import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#wap to find the location of the house where the number 
# of bathroom is min. 2

df[df['bath']>=2][['location','price']].nlargest(5,'price')
# Out:
#               location   price
# 13067   Defence Colony  3600.0
# 11080      Ashok Nagar  2912.0
# 13200   Defence Colony  2800.0
# 11763  Sadashiva Nagar  2736.0
# 3180   Shanthala Nagar  2700.0

# %%
df.nlargest(5,'price')
# Out:
#                   area_type   availability         location        size  \
# 13067            Plot  Area  Ready To Move   Defence Colony  10 Bedroom
# 11080  Super built-up  Area         18-Jan      Ashok Nagar       4 BHK
# 13200            Plot  Area  Ready To Move   Defence Colony   6 Bedroom
# 11763            Plot  Area  Ready To Move  Sadashiva Nagar   5 Bedroom
# 3180   Super built-up  Area  Ready To Move  Shanthala Nagar       5 BHK
#
#        society total_sqft  bath  balcony   price
# 13067      NaN       7150  13.0      NaN  3600.0
# 11080      NaN       8321   5.0      2.0  2912.0
# 13200      NaN       8000   6.0      3.0  2800.0
# 11763      NaN       9600   7.0      2.0  2736.0
# 3180   Kierser       8321   5.0      3.0  2700.0

# %%
#wap to find the price of the house where the 
# location is "Rajaji Nagar".

df[df['location'] == 'Rajaji Nagar']['price']
# Out:
# 7        600.0
# 89       160.0
# 107      229.0
# 324      415.0
# 407      410.0
#          ...
# 12715    105.0
# 12748    650.0
# 12824    225.0
# 12847    165.0
# 13013    245.0
# Name: price, Length: 107, dtype: float64

# %%
# wap to find the house where the number of bathroom is 0.
df[df['bath'] > 0]['price']
# Out:
# 0         39.07
# 1        120.00
# 2         62.00
# 3         95.00
# 4         51.00
#           ...
# 13315    231.00
# 13316    400.00
# 13317     60.00
# 13318    488.00
# 13319     17.00
# Name: price, Length: 13247, dtype: float64

# %%
df.shape
# Out:
# (13320, 9)

# %%
df['bath'].isnull().sum()
# Out:
# 73

# %%
133320 - 73
# Out:
# 133247

# %%
df['bath'].isnull().sum()
# Out:
# 73

# %%
#wap to find the society where the price of 
# the house is in between 500-1000.

df[(df['price'] >=500) & (df['price']<=1000)]
# Out:
#                   area_type   availability             location       size  \
# 7      Super built-up  Area  Ready To Move         Rajaji Nagar      4 BHK
# 62               Plot  Area  Ready To Move           Whitefield  4 Bedroom
# 159              Plot  Area  Ready To Move   Mahalakshmi Layout  4 Bedroom
# 440              Plot  Area  Ready To Move           Whitefield  4 Bedroom
# 539          Built-up  Area  Ready To Move  7th Block Jayanagar  5 Bedroom
# ...                     ...            ...                  ...        ...
# 13019            Plot  Area  Ready To Move        HAL 2nd Stage  5 Bedroom
# 13086  Super built-up  Area  Ready To Move        Sindhi Colony      5 BHK
# 13095  Super built-up  Area  Ready To Move    Sathya Sai Layout      4 BHK
# 13104        Built-up  Area         19-Dec        Church Street      4 BHK
# 13119            Plot  Area  Ready To Move    Sathya Sai Layout  4 Bedroom
#
#        society total_sqft  bath  balcony  price
# ...

# %%
#wap to find the the house where number of balcony is max. 3

df[df['balcony']<=3]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#wap to find the house in "Yemlur" with min size of
# the house is 3bhk.

#wap to find the house in 'Indira nagar' and try to find 
# when you can move into 
# the house.

df[(df['location'] == 'Yemlur') & (df['size'] >= '3BHK')]
# Out:
#            area_type   availability location       size  society total_sqft  \
# 4162  Built-up  Area  Ready To Move   Yemlur  4 Bedroom  Epllan        7000
# 4929      Plot  Area         18-May   Yemlur  8 Bedroom  Epllan       12000
# 7315      Plot  Area         18-Apr   Yemlur  4 Bedroom  Epllan       11000
# 8682      Plot  Area  Ready To Move   Yemlur  4 Bedroom  Epllan        8400
# 9546      Plot  Area  Ready To Move   Yemlur  5 Bedroom  Epllan       10000
#
#       bath  balcony   price
# 4162   5.0      NaN  2050.0
# 4929   9.0      NaN  1900.0
# 7315   5.0      3.0  2000.0
# 8682   5.0      2.0  1675.0
# 9546   5.0      NaN  1950.0

# %%
df[(df['location'] == 'Indira Nagar') & (df['availability'] == 'Ready To Move')].shape[0]
# Out:
# 42

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#wap to find the house in 'Doddathoguru' and also 
# find the size
# of the house.

df[df['location'] == 'Doddathoguru']
# Out:
#                   area_type   availability      location   size  society  \
# 46     Super built-up  Area  Ready To Move  Doddathoguru  2 BHK  LancyRe
# 65     Super built-up  Area  Ready To Move  Doddathoguru  2 BHK      NaN
# 395          Built-up  Area  Ready To Move  Doddathoguru  2 BHK  S onsMa
# 1396   Super built-up  Area  Ready To Move  Doddathoguru  2 BHK  Prianhi
# 1500   Super built-up  Area         18-Apr  Doddathoguru  2 BHK      NaN
# 2822   Super built-up  Area  Ready To Move  Doddathoguru  2 BHK  Arensh
# 2933   Super built-up  Area  Ready To Move  Doddathoguru  3 BHK  SKterAs
# 3559         Built-up  Area  Ready To Move  Doddathoguru  3 BHK  SryleHo
# 3688   Super built-up  Area  Ready To Move  Doddathoguru  2 BHK  Hincy R
# 3710   Super built-up  Area  Ready To Move  Doddathoguru  1 BHK      NaN
# 3872   Super built-up  Area  Ready To Move  Doddathoguru  2 BHK  Vayali
# 3924   Super built-up  Area  Ready To Move  Doddathoguru  2 BHK  Saaveas
# ...
