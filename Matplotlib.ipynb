# %%
import matplotlib.pyplot as plt

# %%
# line chart/plot
# Bar chart
# Pie chart
# Subplot
import numpy as np

# %%
x = np.array([2,4,6,8])
y = np.array([5,10,12,15])
plt.xlabel('sales')
plt.ylabel("months")
plt.title("Sales Analysis")
plt.plot(x,y)

# %%
#wap to create the graph for temp vs days of a city.
#wap to create the graph for temp vs days of two city.

days = ['M','W','F']
temp =[34,12,23]
plt.plot(days,temp)

# %%
days = ['M','W','F']
temp_1 =[34,12,23]
temp_2 = [40,35,20]
plt.plot(days,temp_1,temp_2,marker = 'o',linestyle = 'dotted',color = 'r')

# %%
# plt.bar
# wap to find the marks of a student in eng,maths & science.

# std = 'Ram'
sub = ['eng','maths','science']
marks = [34,33,90]
marks2 = [49,23,32]
plt.bar(sub,marks2)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(sub,marks2)
# Out:
# <BarContainer object of 3 artists>
